# %%
# !pip install jieba wordcloud matplotlib
# Out:
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (0.42.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1d0icZW1GNIKUM_g1UYubsuWufD2So3dw6kxCTgaTtkA/edit?usp=sharing')
# 從 gsheets 的工作表1載入 sheets1
sheets1 = gsheets.worksheet('工作表1').get_all_values()
# 將 sheets1,sheets2,sheets3, 資料載入 pd 的 DataFrame 進行分析
df1 = pd.DataFrame(sheets1[1:], columns=sheets1[0])

# %%
text = df1.columns[0]
text
# Out:
# '台中逢甲、東海等大學近期傳出多名學生遭「無卡分期」集體詐騙。林姓嫌犯透過投資手機、電腦為由，鼓吹學生填寫無卡分期契約，甚至還有北部的學生聽聞簽名就能拿錢，專程南下賺5000元，結果因而欠了上萬債務。\n\n警方指出，通訊行業務員向學生謊稱只需被害人申辦手機或購買筆電等三Ｃ產品，並填寫10萬元無卡分期貸款合約書，即可賺取現金5000元，東海大學還有一名學生拉20名同學一起賺5000元，結果開始被融資公司催討債務後，才知道竟是一場騙局。\n\n據《聯合新聞網》報導，台北大學犯罪學研究所副教授沈伯洋表示，這樣的詐騙手法其實很久以前就存在了，但因是熟人拉攏，學生間沒有戒心，因此很容易上當受騙。另外，近年詐騙手法推陳出新，警政署等也多宣傳於最新的網路詐騙方式，反而讓人對老式的詐騙失去戒心。\n\n報導指出，台師大學務處專責導師室執行長黃志祥透露，通常大學生多會有想實現自己、賺點錢的念頭，但社會歷練仍不足，且該案還涉及債權轉移、利息等問題，也可能是學生金融知識較不足而誤信。\n\n教育部表示，近期接獲9校的14件校安通報，共有89人遭詐騙，已透過大專校安聯繫群組，請各大專校院立即進行校內清查，如有疑似遭詐騙個案應及時通報；同時呼籲學生提高警覺，若遭詐騙應儘快向學校反映，並儘速向警方報案。有多所大學近期傳出學生自傷案，大學導師能否有效解決學生的心理問題，再次引起討論。事實上，目前全台已有五所大學，在導生制外再設置專責導師。以最早創立這個制度的台師大來說，全校35位專責導師，一人負責一個系，平時進行初級輔導，發現高關懷學生再由學校機制介入。\n\n隔著透明隔板，學生和專責導師談心，在台師大只要是上課日，好幾張小桌子不會空太久。\n\n台師大學生曹同學說：「我自己是蠻喜歡找類似輔導老師這樣子的人，但目前是還沒有去過，可是經過的時候會看到，很多人在就是在那邊跟專責導師講話這樣。」\n\n學生有煩惱時想和人談談就過來，對學生來說，不像去心輔中心要等好久。此外，若有緊急狀況，專責導師辦公室還有24小時輪值。\n\n台師大表示，六年前首創專責導師制，目前35位滿編，分別具有心理諮商、輔導和教育專長，其中七位是教官轉職，嫻熟校安事務。平常一位老師負責大學部一個系，主動融入系上活動，也會去訪視在外租屋的學生。\n\n台師大學務處專責導師室執行長黃志祥說明，「他跟學生就有一種很親密的關係，學生就很願意分享他的心情，或是分享一些他的狀況，其他同學有看到這樣狀況，也會很快的反映到專責老師這邊來。」\n\n若發現高關懷學生，轉到心輔或就醫，由整個機制來介入。學務處表示，六年多來幫了不少學生，光去年初級輔導就有9萬多人次，而專責導師也減輕一般導師的負擔。\n\n台師大學務長林玫君表示，「我們很多的老師，他因為升等啊、教學研究，其實說真的是比較忙，所以他要去照顧到一個班的學生五、六十個人，然後要花時間是很辛苦。」\n\n台師大學務處說，專責導師室一年1千4百萬經費，很大一部分是從導師費挪一半過來。這幾年東海、中原等校也有類似制度，做法略有不同，但都希望在最初發現問題並輔導，不致變成危機或憾事。大專院校心輔人力缺，各校出動導師關心導生心理狀態，但台灣大學教授葉丙成日前指出，有些導師未必能有效解決學生心理問題，建議將導師費投入增聘更多心輔人力。對此，台大校長管中閔今表示，已經在討論變革，未來可能會採雙軌，增加學生諮商輔導相關制度。不過，台灣師範大學6年前已採「雙導師」制，以班級為單位設有一名學術與生涯導師，各系另配有一名專責導師。\r\n\r\n葉丙成先前表示，台大學生共有3萬多人，每人有700元左右導生費，總和2000多萬元，可再多聘許多位真正有專業為學生做心理諮商的專業心理師，請學校體認心理輔導必須由專業的人員來做。\r\n\r\n此話一出，也在各大專院校掀起討論。有私立學校基層導師自稱是「導師苦手」，希望替學生多做點什麼，但缺乏輔導諮商專業，平常也被教學工作忙得焦頭爛額，常難以啟齒，也不一定能給學生好的建議。\r\n\r\n政治大學日前召開校務會議，會中有教師提出討論檢討導師制度。一名政大校務會議與會教師透露，會中雖不是正式提案，但有不少教師認為導師制度確實要檢討，自己與很多導師只有學術專長，並沒有輔導專業，若要輔導學生，常是力有未逮。\r\n\r\n「他（指葉丙成）有寫信給我」管中閔表示，學校已經在討論變革，將來可能會有不同的雙軌，增加學生的諮商輔導相關制度。\r\n\r\n事實上，台師大6年前就已將導師費挪作專業輔導人力經費，聘請「專責導師」，也將軍訓室改編制成立「專責導師室」，舊導師轉型為「學術與生涯導師」，另將既有教官，並再增聘教育相關背景人員作為「專責導師」，負責學生的生活事務，學生若遇緊急事件也要即時處理，另兼具輔導功能。\r\n\r\n師大學務長林玫君表示，「專責導師」主要承接昔日教官工作內容，當時把導師費減半，退休教官缺額雖遇缺不補，並保留退休教官的薪資預算，7位退休教官就能請10多位專責導師，目前大學部共有35位專責導師。\r\n\r\n一名今年剛從師大畢業的學生表示，專責導師跟學術導師會在大學入學時，與學生互動並建立關係，專責導師業務百百種，相當關心學生生活，還曾陪同學去看房子，還會適時地殺價，若學生失戀難過、家庭問題，大家也都會去找專責導師，空堂時也可以找老師聊天。\r\n\r\n但有時專責導師可能會跟某些學生群體比較好，他提到，一個系所有2、300名學生，只有一個專責導師，不可能每個人都關心到，但若是有獎學金資訊、講座資訊，專責導師也會主動提供；若是系所選擇及就業選擇，大家就會去找學術導師。'

# %%
import re
import string

cleaned_text = re.sub(r'[。|：|「|（|）|，|\n|」|有|也|是|但|在|\r|專責導|會|就|等|導師|表示|、|就]+'.format(re.escape(string.punctuation)), '', text)
一名政大校務議與教透露中雖不正式提案不少教認為制度確實要檢討自己與很多只學術長並沒輔業若要輔學生常力未逮他指葉丙成寫信給我管中閔學校已經討論變革將來可能不同雙軌增加學生諮商輔相關制度事實上台大6年前已將費挪作業輔人力經費聘請將軍訓室改編制成立室舊轉型為學術與生涯另將既教官並再增聘教育相關背景人員作為負學生生活事務學生若遇緊急事件要即時處理另兼具輔功能大學務長林玫君主要承接昔日教官工作內容當時把費減半退休教官缺額雖遇缺不補並保留退休教官薪資預算7位退休教官能請10多位目前大學部共35位一名今年剛從大畢業學生跟學術大學入學時與學生互動並建立關係業務百百種相當關心學生生活還曾陪同學去看房子還適時地殺價若學生失戀難過家庭問題大家都去找空堂時可以找老聊天時可能跟某些學生群體比較好他提到一個系所2300名學生只一個不可能每個人都關心到若獎學金資訊講座資訊主動提供；若系所選擇及業選擇大家去找學術'

# %%
import jieba
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
seg_list = jieba.cut(cleaned_text, cut_all=False)
words = list(seg_list)

# %%
words
# Out:
# ['台',
#  '中',
#  '逢甲',
#  '東',
#  '海大',
#  '學',
#  '近期',
#  '傳出',
#  '多名',
#  '學生',
#  '遭無卡',
#  '分期',
#  '集體',
#  '詐騙',
#  '林姓',
#  '嫌犯',
#  '透過',
#  '投資手',
#  '機電腦',
#  '為',
#  '由',
#  '鼓吹',
#  '學生',
#  '填寫',
#  '無卡',
#  '分期',
#  '契約',
#  '甚至',
#  '還',
#  '北部',
#  '學生',
#  '聽聞',
#  '簽名',
#  '能',
#  '拿',
#  '錢程',
#  '南下',
#  '賺',
#  '5000',
#  '元',
#  '結果',
#  '因而',
#  '欠',
#  '了',
#  '上',
#  '萬',
#  '債務',
#  '警方',
#  '指出',
#  '通訊',
#  '行業務員',
#  '向',
#  '學生',
#  '謊稱',
#  '只',
#  '需',
#  '被害人',
#  '申辦',
#  '手機',
#  '或',
#  '購買',
#  '筆電三',
#  'Ｃ',
#  '產品',
#  '並填寫',
#  '10',
#  '萬元',
#  '無卡',
#  '分期',
#  '貸款',
#  '合約書',
#  '即可',
#  '賺取',
#  '現金',
#  '5000',
#  '元東',
#  '海大',
#  '學還',
#  '一名',
#  '學生',
#  '拉',
#  '20',
#  '名同學',
#  '一起',
#  '賺',
#  '5000',
#  '元',
#  '結果',
#  '開始',
#  '被',
#  '融資',
#  '公司',
#  '催討',
#  '債務後才',
#  '知道',
#  '竟一場',
#  '騙',
#  '局據',
#  '《',
#  '聯合',
#  '新聞網',
#  '》',
#  '報',
#  '台北',
#  '大學',
#  '犯罪',
#  '學',
#  '研究所',
#  '副教授',
#  '沈伯洋',
#  '這樣',
#  '詐騙',
#  '手法',
#  '其實',
#  '很久以前',
#  '存',
#  '了',
#  '因',
#  '熟人',
#  '拉攏',
#  '學生間',
#  '沒',
#  '戒心',
#  '因此',
#  '很',
#  '容易',
#  '上',
#  '當受',
#  '騙',
#  '另外',
#  '近年',
#  '詐騙',
#  '手法',
#  '推陳',
#  '出新',
#  '警政署',
#  '多',
#  '宣傳',
#  '於',
#  '最新',
#  '網路',
#  '詐騙',
#  '方式',
#  '反而',
#  '讓',
#  '人',
#  '對',
#  '老式',
#  '詐騙',
#  '失去',
#  '戒心',
#  '報',
#  '指出',
#  '台大',
#  '學務',
#  '處室',
#  '執行長',
#  '黃',
#  '志祥',
#  '透露',
#  '通常',
#  '大學生',
#  '多',
#  '想',
#  '實現',
#  '自己',
#  '賺點',
#  '錢念頭',
#  '社歷練',
#  '仍',
#  '不足',
#  '且',
#  '該',
#  '案還',
#  '涉及',
#  '債權',
#  '轉移',
#  '利息',
#  '問題',
#  '可能',
#  '學生',
#  '金融',
#  '知識',
#  '較',
#  '不足',
#  '而',
#  '誤信',
#  '教育部',
#  '近期',
#  '接獲',
#  '9',
#  '校',
#  '14',
#  '件',
#  '校',
#  '安通',
#  '報共',
#  '89',
#  '人',
#  '遭詐',
#  '騙',
#  '已',
#  '透過',
#  '大校',
#  '安',
#  '聯',
#  '繫',
#  '群',
#  '組',
#  '請',
#  '各',
#  '大校',
#  '院',
#  '立即',
#  '進行校',
#  '內',
#  '清查',
#  '如',
#  '疑似',
#  '遭詐',
#  '騙個',
#  '案應',
#  '及',
#  '時',
#  '通報',
#  '；',
#  '同時',
#  '呼籲',
#  '學生',
#  '提高',
#  '警覺',
#  '若',
#  '遭詐',
#  '騙',
#  '應',
#  '儘',
#  '快',
#  '向',
#  '學',
#  '校',
#  '反映',
#  '並',
#  '儘',
#  '速',
#  '向',
#  '警方',
#  '報案',
#  '多所',
#  '大學',
#  '近期',
#  '傳出',
#  '學生',
#  '自傷',
#  '案大學',
#  '能否',
#  '效解',
#  '決學生',
#  '心理',
#  '問題',
#  '再次',
#  '引起',
#  '討論',
#  '事實',
#  '上',
#  '目前',
#  '全台',
#  '已',
#  '五所',
#  '大學生',
#  '制外',
#  '再',
#  '設置',
#  '以',
#  '最早',
#  '創立',
#  '這個',
#  '制度',
#  '台大',
#  '來',
#  '說',
#  '全校',
#  '35',
#  '位一人',
#  '負一個',
#  '系平時',
#  '進行',
#  '初級',
#  '輔',
#  '發現',
#  '高關',
#  '懷學生',
#  '再',
#  '由',
#  '學校',
#  '機制',
#  '介入',
#  '隔著',
#  '透明',
#  '隔板',
#  '學生',
#  '和',
#  '談心',
#  '台大',
#  '只要',
#  '上',
#  '課日',
#  '好',
#  '幾張',
#  '小桌子',
#  '不空',
#  '太久',
#  '台大',
#  '學生',
#  '曹同學',
#  '說',
#  '我',
#  '自己',
#  '蠻',
#  '喜歡',
#  '找類',
#  '似輔',
#  '老',
#  '這樣子',
#  '人',
#  '目前',
#  '還沒去',
#  '過可經過',
#  '時候',
#  '看到',
#  '很多',
#  '人',
#  '那邊',
#  '跟',
#  '講話',
#  '這樣',
#  '學生',
#  '煩惱',
#  '時',
#  '想',
#  '和',
#  '人談',
#  '談過',
#  '來',
#  '對',
#  '學生',
#  '來',
#  '說',
#  '不',
#  '像',
#  '去',
#  '心輔',
#  '中心',
#  '要',
#  '好久',
#  '此外',
#  '若緊',
#  '急',
#  '狀況',
#  '辦',
#  '公室',
#  '還',
#  '24',
#  '小時',
#  '輪值',
#  '台大',
#  '六年',
#  '前首',
#  '創制',
#  '目前',
#  '35',
#  '位滿',
#  '編分',
#  '別具',
#  '心理',
#  '諮',
#  '商輔',
#  '和',
#  '教育',
#  '長',
#  '其中',
#  '七位',
#  '教官',
#  '轉職',
#  '嫻熟',
#  '校安事務',
#  '平常',
#  '一位',
#  '老負',
#  '大學部',
#  '一個',
#  '系主動',
#  '融入',
#  '系上',
#  '活動',
#  '去',
#  '訪視外',
#  '租屋',
#  '學生',
#  '台大',
#  '學務',
#  '處室',
#  '執行長',
#  '黃',
#  '志祥',
#  '說明',
#  '他',
#  '跟',
#  '學生',
#  '一種',
#  '很',
#  '親密關',
#  '係',
#  '學生',
#  '很',
#  '願意',
#  '分享',
#  '他',
#  '心情',
#  '或',
#  '分享',
#  '一些',
#  '他',
#  '狀況',
#  '其他',
#  '同學',
#  '看到',
#  '這樣',
#  '狀況',
#  '很快',
#  '反映',
#  '到',
#  '老',
#  '這邊',
#  '來',
#  '若',
#  '發現',
#  '高關',
#  '懷學生',
#  '轉到',
#  '心輔',
#  '或',
#  '醫由',
#  '整個',
#  '機制',
#  '來',
#  '介入',
#  '學務處',
#  '六年',
#  '多來',
#  '幫',
#  '了',
#  '不少',
#  '學',
#  '生光',
#  '去年初',
#  '級輔',
#  '9',
#  '萬',
#  '多人次',
#  '而',
#  '減輕',
#  '一般',
#  '負擔',
#  '台大',
#  '學務長',
#  '林玫君',
#  '我們',
#  '很多',
#  '老',
#  '他',
#  '因為',
#  '升',
#  '啊',
#  '教學',
#  '研究',
#  '其實',
#  '說',
#  '真',
#  '比',
#  '較',
#  '忙',
#  '所以',
#  '他',
#  '要',
#  '去',
#  '照顧',
#  '到',
#  '一個',
#  '班學生',
#  '五六十',
#  '個',
#  '人然後要',
#  '花',
#  '時間',
#  '很',
#  '辛苦',
#  '台大',
#  '學務處',
#  '說室',
#  '一年',
#  '1',
#  '千',
#  '4',
#  '百萬經費',
#  '很大',
#  '一部分',
#  '從費',
#  '挪',
#  '一半',
#  '過來',
#  '這幾年',
#  '東海',
#  '中原',
#  '校類',
#  '似',
#  '制度',
#  '做法',
#  '略',
#  '不同',
#  '都',
#  '希望',
#  '最初',
#  '發現',
#  '問題',
#  '並輔',
#  '不致',
#  '變成',
#  '危機',
#  '或',
#  '憾事',
#  '大',
#  '院校',
#  '心輔',
#  '人力',
#  '缺',
#  '各校',
#  '出動關',
#  '心生',
#  '心理',
#  '狀態',
#  '台灣',
#  '大學',
#  '教授',
#  '葉丙成',
#  '日前',
#  '指出',
#  '些',
#  '未必',
#  '能效',
#  '解決',
#  '學生',
#  '心理',
#  '問題',
#  '建議',
#  '將費',
#  '投入',
#  '增聘',
#  '更',
#  '多心',
#  '輔',
#  '人力',
#  '對',
#  '此台',
#  '大校',
#  '長',
#  '管中',
#  '閔今',
#  '已經',
#  '討論',
#  '變革',
#  '未來',
#  '可能',
#  '採雙軌',
#  '增加',
#  '學生',
#  '諮',
#  '商輔',
#  '相關',
#  '制度',
#  '不過',
#  '台灣',
#  '範大學',
#  '6',
#  '年前',
#  '已',
#  '採雙制',
#  '以班級',
#  '為',
#  '單位',
#  '設',
#  '一名',
#  '學術',
#  '與',
#  '生涯',
#  '各系',
#  '另配',
#  '一名',
#  '葉丙成',
#  '先前',
#  '台大',
#  '學生',
#  '共',
#  '3',
#  '萬多人',
#  '每人',
#  '700',
#  '元',
#  '左右',
#  '生費',
#  '總',
#  '和',
#  '2000',
#  '多萬元',
#  '可',
#  '再',
#  '多聘許',
#  '多位',
#  '真正',
#  '業為',
#  '學生',
#  '做',
#  '心理',
#  '諮',
#  '商業',
#  '心理',
#  '請學校',
#  '體認',
#  '心理',
#  '輔必須',
#  '由業',
#  '人員來',
#  '做',
#  '此話',
#  '一出',
#  '各大',
#  '院校',
#  '掀起',
#  '討論',
#  '私立',
#  '學校',
#  '基層',
#  '自稱',
#  '苦手',
#  '希望',
#  '替學生',
#  '多',
#  '做點',
#  '什麼',
#  '缺乏',
#  '輔',
#  '諮',
#  '商業',
#  '平常',
#  '被',
#  '教學',
#  '工作',
#  '忙',
#  '得',
#  '焦頭爛',
#  '額常難',
#  '以',
#  '啟齒',
#  '不',
#  '一定',
#  '能給',
#  '學生',
#  '好',
#  '建議',
#  '政治',
#  '大學',
#  '日前',
#  '召開',
#  '校務議',
#  '中教',
#  '提出',
#  '討論',
#  '檢討',
#  '制度',
#  '一名',
#  '政',
#  '大校',
#  '務議',
#  '與',
#  '教',
#  '透露',
#  '中',
#  '雖',
#  '不',
#  '正式',
#  '提案',
#  '不少',
#  '教認',
#  '為',
#  '制度',
#  '確實要',
#  '檢討',
#  '自己',
#  '與',
#  '很多',
#  '只學術長',
#  '並沒輔業',
#  '若',
#  '要',
#  '輔學',
#  '生常力',
#  '未',
#  '逮',
#  '他',
#  '指葉丙成',
#  '寫',
#  '信給',
#  '我',
#  '管中',
#  '閔學校',
#  '已經',
#  '討論',
#  '變革',
#  '將來',
#  '可能',
#  '不同',
#  '雙軌',
#  '增加',
#  '學生',
#  '諮',
#  '商輔',
#  '相關',
#  '制度',
#  '事實',
#  '上台',
#  '大',
#  '6',
#  '年前',
#  '已將費',
#  '挪作',
#  '業輔',
#  '人力',
#  '經費聘',
#  '請',
#  '將軍訓室',
#  '改編制',
#  '成立',
#  '室舊',
#  '轉型',
#  '為',
#  '學術',
#  '與',
#  '生涯',
#  '另將',
#  '既',
#  '教官',
#  '並再',
#  '增聘',
#  '教育',
#  '相關',
#  '背景',
#  '人員作',
#  '為',
#  '負學生',
#  '生活',
#  '事務學',
#  '生若遇',
#  '緊急',
#  '事件',
#  '要',
#  '即',
#  '時',
#  '處理',
#  '另',
#  '兼具',
#  '輔',
#  '功能',
#  '大學務長',
#  '林',
#  '玫',
#  '君主',
#  '要',
#  '承接',
#  '昔日',
#  '教官',
#  '工作',
#  '內容',
#  '當時',
#  '把費',
#  '減半',
#  '退休',
#  '教官',
#  '缺額',
#  '雖遇',
#  '缺不補並',
#  '保留',
#  '退休',
#  '教官',
#  '薪資',
#  '預算',
#  '7',
#  '位',
#  '退休',
#  '教官',
#  '能',
#  '請',
#  '10',
#  '多位',
#  '目前',
#  '大學部',
#  '共',
#  '35',
#  '位',
#  '一名',
#  '今年',
#  '剛從',
#  '大',
#  '畢業',
#  '學生',
#  '跟',
#  '學術',
#  '大學入',
#  '學時',
#  '與',
#  '學生',
#  '互動並',
#  '建立',
#  '關',
#  '係',
#  '業務百百種',
#  '相當關',
#  '心學生',
#  '生活',
#  '還曾',
#  '陪同',
#  '學去',
#  '看',
#  '房子',
#  '還適',
#  '時',
#  '地',
#  '殺',
#  '價若學生',
#  '失戀',
#  '難過',
#  '家庭',
#  '問題',
#  '大家',
#  '都',
#  '去',
#  '找空',
#  '堂時',
#  '可以',
#  '找',
#  '老',
#  '聊天',
#  '時',
#  '可能',
#  '跟',
#  '某些',
#  '學生',
#  '群體',
#  '比',
#  '較',
#  '好',
#  '他',
#  '提到',
#  '一個',
#  '系',
#  '所',
#  '2300',
#  '名學生',
#  '只',
#  '一個',
#  '不',
#  '可能',
#  '每個',
#  '人',
#  '都',
#  '關心',
#  '到',
#  '若',
#  '獎學',
#  '金資訊',
#  '講座',
#  '資訊主動',
#  '提供',
#  '；',
#  '若系',
#  '所',
#  '選擇',
#  '及業',
#  '選擇',
#  '大家',
#  '去',
#  '找',
#  '學術']

# %%
word_freq = Counter(words)
print(word_freq)
# Out:
# Counter({'學生': 24, '台大': 9, '心理': 7, '他': 7, '制度': 6, '教官': 6, '詐騙': 5, '為': 5, '一名': 5, '人': 5, '問題': 5, '可能': 5, '時': 5, '討論': 5, '來': 5, '去': 5, '要': 5, '諮': 5, '與': 5, '學': 4, '上': 4, '或': 4, '騙': 4, '大學': 4, '很': 4, '大校': 4, '若': 4, '目前': 4, '說': 4, '輔': 4, '和': 4, '老': 4, '跟': 4, '不': 4, '一個': 4, '學術': 4, '近期': 3, '分期': 3, '5000': 3, '元': 3, '了': 3, '指出': 3, '向': 3, '這樣': 3, '多': 3, '對': 3, '自己': 3, '較': 3, '校': 3, '遭詐': 3, '已': 3, '請': 3, '再': 3, '35': 3, '發現': 3, '好': 3, '很多': 3, '心輔': 3, '狀況': 3, '商輔': 3, '到': 3, '都': 3, '大': 3, '人力': 3, '相關': 3, '退休': 3, '中': 2, '海大': 2, '傳出
疑似': 1, '騙個': 1, '案應': 1, '及': 1, '通報': 1, '同時': 1, '呼籲': 1, '提高': 1, '警覺': 1, '應': 1, '快': 1, '並': 1, '速': 1, '報案': 1, '多所': 1, '自傷': 1, '案大學': 1, '能否': 1, '效解': 1, '決學生': 1, '再次': 1, '引起': 1, '全台': 1, '五所': 1, '制外': 1, '設置': 1, '最早': 1, '創立': 1, '這個': 1, '全校': 1, '位一人': 1, '負一個': 1, '系平時': 1, '進行': 1, '初級': 1, '隔著': 1, '透明': 1, '隔板': 1, '談心': 1, '只要': 1, '課日': 1, '幾張': 1, '小桌子': 1, '不空': 1, '太久': 1, '曹同學': 1, '蠻': 1, '喜歡': 1, '找類': 1, '似輔': 1, '這樣子': 1, '還沒去': 1, '過可經過': 1, '時候': 1, '那邊': 1, '講話': 1, '煩惱': 1, '人談': 1, '談過': 1, '像': 1, '中心': 1, '好久': 1, '此外': 1, '若緊': 1, '急': 1, '辦': 1, '公室': 1, '24': 1, '小時': 1, '輪值': 1, '前首': 1, '創制': 1, '位滿': 1, '編分': 1, '別具': 1, '其中': 1, '七位': 1, '轉職': 1, '嫻熟': 1, '校安事務': 1, '一位': 1, '老負': 1, '系主動': 1, '融入': 1, '系上': 1, '活動': 1, '訪視外': 1, '租屋': 1, '說明': 1, '一種': 1, '親密關': 1, '願意': 1, '心情': 1, '一些': 1, '其他': 1, '同學': 1, '很快': 1, '這邊': 1, '轉到': 1, '醫由': 1, '整個': 1, '多來': 1, '幫': 1, '生光': 1, '去年初': 1, '級輔': 1, '多人次': 1, '減輕': 1, '一般': 1, '負擔': 1, '學務長': 1, '林玫君': 1, '我們': 1, '因為': 1, '升': 1, '啊': 1, '研究': 1, '真': 1, '所以': 1, '照顧': 1, '班學生': 1, '五六十': 1, '個': 1, '人然後要': 1, '花': 1, '時間': 1, '辛苦': 1, '說室': 1, '一年': 1, '1': 1, '千': 1, '4': 1, '百萬經費': 1, '很大': 1, '一部分': 1, '從費': 1, '挪': 1, '一半': 1, '過來': 1, '這幾年': 1, '東海': 1, '中原': 1, '校類': 1, '似': 1, '做法': 1, '略': 1, '最初': 1, '並輔': 1, '不致': 1, '變成': 1, '危機': 1, '憾事': 1, '缺': 1, '各校': 1, '出動關': 1, '心生': 1, '狀態': 1, '教授': 1, '些': 1, '未必': 1, '能效': 1, '解決': 1, '將費': 1, '投入': 1, '更': 1, '多心': 1, '此台': 1, '閔今': 1, '未來': 1, '採雙軌': 1, '不過': 1, '範大學': 1, '採雙制': 1, '以班級': 1, '單位': 1, '設': 1, '各系': 1, '另配': 1, '先前':  ...

# %%
# !apt-get -qq install -y fonts-noto-cjk

# %%
font_path = "/usr/share/fonts/truetype/noto/NotoSansCJK-Regular.ttc"
wc = WordCloud(font_path=font_path, background_color="white", max_words=2000, width=800, height=600)
wordcloud = wc.generate_from_frequencies(word_freq)

# %%
# 显示文字云
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)
