# %%
import requests
from bs4 import BeautifulSoup

# %%
# 定义要抓取的页数范围
start_page = 1
end_page = 10

# %%
test_url = url 
response_test = requests.get(url)
response_test
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response_test.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 KoreaStar 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/KoreaStar/index.html"><span class="board-label">看板 </span>KoreaStar</a>
# <a class="right small" href="/about.html">關於我們</a>
# ...

# %%
soup = BeautifulSoup(response_test.text, 'html.parser')
listtitle = soup.find_all('div', class_='title')
listtitle
# Out:
# [<div class="title">
#  <a href="/bbs/KoreaStar/M.1240122982.A.77D.html">[新聞] 傳李英愛被邀演白素貞 投資方回應：正接洽</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240123276.A.5A4.html">[新聞] 李準基公開《J Style》MV 效果媲美大片</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240123842.A.A27.html">[美圖] 《男版灰姑娘》海報曝光 權相宇華麗出鏡</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240124555.A.95E.html">[情報] 朴施厚基本資料</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240149766.A.6A4.html">[請益] 請問張東健的這首廣告歌</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240153386.A.C4E.html">[討論] 有沒有人喜歡李奎漢阿?</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240153728.A.99C.html">[情報] Wonder Girls 基本資料</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240164160.A.FDE.html">[情報] 金成玲基本資料</a>
#  </div>,
#  <div class="title">
#  <a href="/bbs/KoreaStar/M.1240196554.A.19E.html">[新聞] 韓版F4攻日亮相60秒 粉絲批受辱</a>
#  </div>,
# ...

# %%
listtitle[0]
# Out:
# <div class="title">
# <a href="/bbs/KoreaStar/M.1240122982.A.77D.html">[新聞] 傳李英愛被邀演白素貞 投資方回應：正接洽</a>
# </div>

# %%
listtitle[0].a.string
# Out:
# '[新聞] 傳李英愛被邀演白素貞 投資方回應：正接洽'

# %%
listtitle[0].a['href']
# Out:
# '/bbs/KoreaStar/M.1240122982.A.77D.html'

# %%
path= 'https://www.ptt.cc'+ listtitle[0].a['href']
path
# Out:
# 'https://www.ptt.cc/bbs/KoreaStar/M.1240122982.A.77D.html'

# %%
response_page = requests.get(path)
response_page.text

soup_page = BeautifulSoup(response_page.text,'html.parser')
itemname = soup_page.find_all('span',class_='article-meta-value')
itemname[0].string
# Out:
# 'xinyuxiao (果果子)'

# %%
content_page = soup_page.find_all('div',class_="bbs-screen bbs-content")
content_page
# Out:
# [<div class="bbs-screen bbs-content" id="main-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">xinyuxiao (果果子)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Korea_Star</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[新聞] 傳李英愛被邀演白素貞 投資方回應：正接洽</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Apr 19 14:36:20 2009</span></div>
#  中新網4月17日電
#
#    日前，有投資方傳出將斥資七千萬元人民幣重新翻拍《新白娘子傳奇》
#  ，再現“白娘子”的經典形象，立即吸引了人們的眼球和眾多媒體的關注視線，激起了線
#  民的熱烈討論。
#
#  　　最近，多家主流門戶網站也都對新版的白娘子、許仙、小青等主角進行票選徵集活動
#  ，獲得了網友的積極回應。其中金喜善、李英愛、賈靜雯、範冰冰等人人在白娘子征選中
#  贏得了眾多網友的支持人氣一直居高不下。
#
#  　　誰會出演新版“白娘子”，挑戰老版趙雅芝“白娘子”的經典形象？毫無疑問地成為
#  時下最熱門的話題。針對網上的討論，記者採訪了該劇的出品方，柯瑞傳媒宣傳策劃部總
#  監謝曉虎。他說，《又見白娘子》這部電視劇的成功與否，選對白素貞的人選將會成功一
#  半，所以這個是我們最慎重，也是目前最頭疼的一件事，目前我們還在海選過程中。
#
# ...
