# %%
import pandas as pd

# 設定 CSV 檔案的路徑
csv_file_path_111 = '111.csv'
csv_file_path_112 = '112.csv'

# 使用 pandas 的 read_csv 函式讀取 CSV 檔案並將其轉換為 DataFrame
df_111 = pd.read_csv(csv_file_path_111)
df_112 = pd.read_csv(csv_file_path_112)

# %%
df_111
# Out:
#              中文課程名稱
# 0             能源與動力
# 1               統計學
# 2              專業實習
# 3          人力資源資訊系統
# 4         薪酬設計與績效管理
# 5          工業科技教育概論
# 6              基本設計
# 7              電子電路
# 8          人力資源發展概論
# 9             計算機概論
# 10           電腦影像處理
# 11             機械製造
# 12             木工製造
# 13             作業系統
# 14          工業安全與衛生
# 15           網際網路概論
# 16              色彩學
# 17           電腦輔助製圖
# 18        訓練需求與成效評估
# 19             程式語言
# 20             展示設計
# 21             機構設計
# 22       多媒體教材設計與製作
# 23        金屬產品設計與製作
# 24            資料庫系統
# 25        電腦網路原理與實作
# 26             產品設計
# 27  生活科技科教學實習（一）（教）
# 28          產品分析與企劃
# 29           虛擬實境設計
# 30          專題製作（二）
# 31          專題製作（二）
# 32          專題製作（二）
# 33          專題製作（二）
# 34          專題製作（二）
# 35        電腦輔助設計與製造

# %%
df_112
# Out:
#              中文課程名稱
# 0        教育資料探勘專題製作
# 1         教育大數據專題製作
# 2              專業實習
# 3          人力資源資訊系統
# 4        企業員工生涯管理研究
# 5            科技專案管理
# 6             計算機概論
# 7          工業科技教育概論
# 8              基本設計
# 9          人力資源發展概論
# 10           電腦影像處理
# 11             電子電路
# 12             機械製造
# 13             木工製造
# 14             作業系統
# 15             組織行為
# 16           網際網路概論
# 17              色彩學
# 18           電腦輔助製圖
# 19        訓練需求與成效評估
# 20             程式語言
# 21             展示設計
# 22       多媒體教材設計與製作
# 23            資料庫系統
# 24        電腦網路原理與實作
# 25             產品設計
# 26  生活科技科教學實習（一）（教）
# 27          產品分析與企劃
# 28           虛擬實境設計
# 29          專題製作（二）
# 30          專題製作（二）
# 31          專題製作（二）
# 32          專題製作（二）
# 33          專題製作（二）
# 34        電腦輔助設計與製造

# %%
# 從 DataFrame 中取出課程名稱欄位，假設欄位名稱為 '課程名稱'，你可以根據實際情況調整
class_names_111 = df_111['中文課程名稱']
class_names_112 = df_112['中文課程名稱']


# 將課程名稱轉換為 set 資料型態
class_names_111_set = set(class_names_111)
class_names_112_set = set(class_names_112)

#111跟112同時開的課程

# %%
class_names_111_set & class_names_112_set
# Out:
# {'人力資源發展概論',
#  '人力資源資訊系統',
#  '作業系統',
#  '基本設計',
#  '多媒體教材設計與製作',
#  '專業實習',
#  '專題製作（二）',
#  '展示設計',
#  '工業科技教育概論',
#  '木工製造',
#  '機械製造',
#  '生活科技科教學實習（一）（教）',
#  '產品分析與企劃',
#  '產品設計',
#  '程式語言',
#  '網際網路概論',
#  '色彩學',
#  '虛擬實境設計',
#  '計算機概論',
#  '訓練需求與成效評估',
#  '資料庫系統',
#  '電子電路',
#  '電腦影像處理',
#  '電腦網路原理與實作',
#  '電腦輔助製圖',
#  '電腦輔助設計與製造'}
