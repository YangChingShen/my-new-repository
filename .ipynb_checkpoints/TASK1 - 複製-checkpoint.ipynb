# %%
import pandas as pd

# 設定 CSV 檔案的路徑
csv_file_path_1= '1.csv'
csv_file_path_2 = '2.csv'

# 使用 pandas 的 read_csv 函式讀取 CSV 檔案並將其轉換為 DataFrame
df_1 = pd.read_csv(csv_file_path_1)
df_2 = pd.read_csv(csv_file_path_2)

# %%
df_1
# Out:
#     111學年度全國大專校院及校長名錄(含學校本部地址) Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0               匯出時間:111.12.22        NaN        NaN        NaN
# 1                           序號       學校代碼        公私立         體制
# 2                            1       0001         公立       一般大學
# 3                            2       0002         公立       一般大學
# 4                            3       0003         公立       一般大學
# ..                         ...        ...        ...        ...
# 155                        154       1R07         私立     宗教研修學院
# 156                        155       1R08         私立     宗教研修學院
# 157                        156       1R09         私立     宗教研修學院
# 158                        157       3002         公立       一般大學
# 159                        158       3A01         公立       空中大學
#
#                 Unnamed: 4                                     Unnamed: 5  \
# 0                      NaN                                            NaN
# 1                     學校名稱                                         學校英文名稱
# 2                   國立政治大學                   National Chengchi University
# 3                   國立清華大學                  National Tsing Hua University
# 4                   國立臺灣大學                     National Taiwan University
# ..                     ...                                            ...
# 155          台灣基督長老教會南神神學院                     Tainan Theological College
# 156  基督教華神學校財團法人中華福音神學研究學院  China Evangelical Graduate School of Theology
# 157                 唯心聖教學院                       Weixin Shengjiao College
# 158                 臺北市立大學                           University of Taipei
# 159               高雄市立空中大學                   Open University of Kaohsiung
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0          NaN        NaN        NaN        NaN         NaN
# 1           職稱         姓名        縣市別     第三級行政區        郵遞區號
# 2           校長        李蔡彥        臺北市        文山區      116011
# 3           校長        高為元        新竹市        新竹市      300044
# 4           校長        管中閔        臺北市        大安區      106319
# ..         ...        ...        ...        ...         ...
# 155         校長        胡忠銘        臺南市        東　區      701002
# 156         校長        戴繼宗        桃園市        八德區      334025
# 157         校長        陳立岳        南投縣        南投市      540022
# 158         校長        邱英浩        臺北市        中正區      100234
# 159         校長        劉嘉茹        高雄市        小港區      812008
#
#            Unnamed: 11   Unnamed: 12   Unnamed: 13                 Unnamed: 14
# 0                  NaN           NaN           NaN                         NaN
# 1                 學校地址          學校總機          學校傳真                          網址
# 2       臺北市文山區指南路2段64號  02-2939-3091  02-2937-9611      http://www.nccu.edu.tw
# 3         新竹市光復路2段101號   03-571-5131   03-572-4038      http://www.nthu.edu.tw
# 4       臺北市大安區羅斯福路4段1號  02-3366-3366  02-2362-7651       http://www.ntu.edu.tw
# ..                 ...           ...           ...                         ...
# 155     臺南市東區東門路一段117號   06-237-1291   06-234-6060     http://www.ttcs.edu.tw/
# 156       桃園市八德區長安街53號   03-273-7477   03-371-4703       http://wp.ces.org.tw/
# 157  南投縣南投市文化路705巷667號  049-220-9418  049-220-3351    http://www.wxsjc.edu.tw/
# 158       臺北市中正區愛國西路1號  02-2311-3040  02-2381-4067  http://www.utaipei.edu.tw/
# 159     高雄市小港區大業北路436號   07-801-2008   07-806-6725       http://www.ouk.edu.tw
#
# [160 rows x 15 columns]

# %%
df_112
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_112
#
# NameError: name 'df_112' is not defined

# %%
# 從 DataFrame 中取出課程名稱欄位，假設欄位名稱為 '課程名稱'，你可以根據實際情況調整
class_names_111 = df_111['中文課程名稱']
class_names_112 = df_112['中文課程名稱']


# 將課程名稱轉換為 set 資料型態
class_names_111_set = set(class_names_111)
class_names_112_set = set(class_names_112)

#111跟112同時開的課程
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 從 DataFrame 中取出課程名稱欄位，假設欄位名稱為 '課程名稱'，你可以根據實際情況調整
# ----> 2 class_names_111 = df_111['中文課程名稱']
#       3 class_names_112 = df_112['中文課程名稱']
#       6 # 將課程名稱轉換為 set 資料型態
#
# NameError: name 'df_111' is not defined

# %%
class_names_111_set & class_names_112_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 class_names_111_set & class_names_112_set
#
# NameError: name 'class_names_111_set' is not defined
